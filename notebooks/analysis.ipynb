# %%
import sys
import os

# Add the project root to sys.path (one level up from notebooks/)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

# %%
from src.data.fetch_data import fetch_option_data
from src.solvers.root_finders import *
from src.plotting.vol_surface_plot import generate_iv_surface
from src.volatility.implied_vol import compute_data_iv

# %%
from datetime import date, timedelta

# %%
# Get today's date
start_date = date.today()

# Compute one month from today (approx 30 days)
end_date = start_date + timedelta(days=30)

# Convert to string format (YYYY-MM-DD)
start_date = start_date.strftime("%Y-%m-%d")
end_date = end_date.strftime("%Y-%m-%d")

ticker = "AAPL"
r = 0.045
q = 0.005

options_df, spot_price = fetch_option_data(ticker, start_date, end_date)

data_with_iv = compute_data_iv(options_df, spot_price, r, q, verbose = False)
generate_iv_surface(data_with_iv, ticker, plot = True)
# Out:
# c:\Users\oussa\Desktop\Implied_Volatility_Surface\src\data\fetch_data.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls['midPrice'] = 0.5 * (calls['bid'] + calls['ask'])
# c:\Users\oussa\Desktop\Implied_Volatility_Surface\src\data\fetch_data.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls['timeToMaturity'] = T
# c:\Users\oussa\Desktop\Implied_Volatility_Surface\src\data\fetch_data.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls['midPrice'] = 0.5 * (calls['bid'] + calls['ask'])
# c:\Users\oussa\Desktop\Implied_Volatility_Surface\src\data\fetch_data.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls['timeToMaturity'] = T
# c:\Users\oussa\Desktop\Implied_Volatility_Surface\src\data\fetch_data.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls['midPrice'] = 0.5 * (calls['bid'] + calls['ask'])
# c:\Users\oussa\Desktop\Implied_Volatility_Surface\src\data\fetch_data.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls['timeToMaturity'] = T
# c:\Users\oussa\Desktop\Implied_Volatility_Surface\src\data\fetch_data.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls['midPrice'] = 0.5 * (calls['bid'] + calls['ask'])
# c:\Users\oussa\Desktop\Implied_Volatility_Surface\src\data\fetch_data.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls['timeToMaturity'] = T
# Fetched 178 options between 2025-11-14 and 2025-12-05.
